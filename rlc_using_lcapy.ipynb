# %%
from lcapy import Circuit, s
cct = Circuit("""
V1 1 0 {u(t)}; down
R1 1 2 4; right=1.5
L1 2 3 0.1; right=1.5
C1 3 4 0.001; down=1.5
W1 0 4; right
""")
cct.draw()

# %%
# %matplotlib inline
ax = cct[2].v.plot()

# %%
# %matplotlib inline
ax = cct[3].v.plot()

# %%
# %matplotlib inline
ax = cct.R1.i.plot()
